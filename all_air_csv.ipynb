# %%
import pandas as pd
import os

# %%
file_list = [f for f in os.listdir('../bcn_open_data/Aire') if f.endswith('.csv')]
print(file_list)
# Out:
# ['2019_04_Abril_qualitat_aire_BCN.csv', '2019_05_Maig_qualitat_aire_BCN.csv', '2019_06_Juny_qualitat_aire_BCN.csv', '2019_07_Juliol_qualitat_aire_BCN.csv', '2019_08_Agost_qualitat_aire_BCN.csv', '2019_09_Setembre_qualitat_aire_BCN.csv', '2019_10_Octubre_qualitat_aire_BCN.csv', '2020_03_Marc_qualitat_aire_BCN.csv', '2020_04_Abril_qualitat_aire_BCN.csv', '2020_05_Maig_qualitat_aire_BCN.csv', '2020_06_Juny_qualitat_aire_BCN.csv', '2020_07_Juliol_qualitat_aire_BCN.csv', '2020_08_Agost_qualitat_aire_BCN.csv', '2020_09_Setembre_qualitat_aire_BCN.csv', '2020_10_Octubre_qualitat_aire_BCN.csv']

# %%
data_sets = [pd.read_csv(os.path.join('../bcn_open_data/Aire', f)) for f in file_list]
data = pd.concat(data_sets, axis=0)
data.head(100)
# Out:
#     CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 0              8.0  Barcelona           19.0  Barcelona      4.0
# 1              8.0  Barcelona           19.0  Barcelona      4.0
# 2              8.0  Barcelona           19.0  Barcelona      4.0
# 3              8.0  Barcelona           19.0  Barcelona      4.0
# 4              8.0  Barcelona           19.0  Barcelona      4.0
# ..             ...        ...            ...        ...      ...
# 95             8.0  Barcelona           19.0  Barcelona      4.0
# 96             8.0  Barcelona           19.0  Barcelona      4.0
# 97             8.0  Barcelona           19.0  Barcelona      4.0
# 98             8.0  Barcelona           19.0  Barcelona      4.0
# 99             8.0  Barcelona           19.0  Barcelona      4.0
#
#     CODI_CONTAMINANT     ANY  MES   DIA   H01  ... V20   H21 V21   H22 V22  \
# 0                7.0  2019.0  4.0   2.0   1.0  ...   V   3.0   V   1.0   V
# ...

# %%
april = pd.read_csv('../bcn_open_data/Aire/2019_04_Abril_qualitat_aire_BCN.csv')

# %%
april
# Out:
#       CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 0                  8  Barcelona             19  Barcelona        4
# 1                  8  Barcelona             19  Barcelona        4
# 2                  8  Barcelona             19  Barcelona        4
# 3                  8  Barcelona             19  Barcelona        4
# 4                  8  Barcelona             19  Barcelona        4
# ...              ...        ...            ...        ...      ...
# 1126               8  Barcelona             19  Barcelona       57
# 1127               8  Barcelona             19  Barcelona       57
# 1128               8  Barcelona             19  Barcelona       57
# 1129               8  Barcelona             19  Barcelona       57
# 1130               8  Barcelona             19  Barcelona       57
#
#       CODI_CONTAMINANT   ANY  MES  DIA   H01  ...   H20  V20   H21  V21   H22  \
# 0                    7  2019    4    2   1.0  ...   8.0    V   3.0    V   1.0
# ...
