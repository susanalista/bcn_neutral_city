# %% [markdown]
# ## Splitting "Air Measurements" csv by year

# %%
import pandas as pd
import os

# %%
file_list = [f for f in os.listdir('../bcn_open_data/Aire/2019') if f.endswith('.csv')]
print(file_list)
# Out:
# ['2019_04_Abril_qualitat_aire_BCN.csv', '2019_05_Maig_qualitat_aire_BCN.csv', '2019_06_Juny_qualitat_aire_BCN.csv', '2019_07_Juliol_qualitat_aire_BCN.csv', '2019_08_Agost_qualitat_aire_BCN.csv', '2019_09_Setembre_qualitat_aire_BCN.csv', '2019_10_Octubre_qualitat_aire_BCN.csv']

# %%
data_sets = [pd.read_csv(os.path.join('../bcn_open_data/Aire/2019', f)) for f in file_list]
data = pd.concat(data_sets, axis=0)
data.head()
# Out:
#    CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 0             8.0  Barcelona           19.0  Barcelona      4.0
# 1             8.0  Barcelona           19.0  Barcelona      4.0
# 2             8.0  Barcelona           19.0  Barcelona      4.0
# 3             8.0  Barcelona           19.0  Barcelona      4.0
# 4             8.0  Barcelona           19.0  Barcelona      4.0
#
#    CODI_CONTAMINANT     ANY  MES  DIA  H01  ... V20  H21 V21  H22 V22  H23  \
# 0               7.0  2019.0  4.0  2.0  1.0  ...   V  3.0   V  1.0   V  1.0
# 1               7.0  2019.0  4.0  3.0  1.0  ...   V  2.0   V  2.0   V  2.0
# 2               7.0  2019.0  4.0  4.0  1.0  ...   V  2.0   V  1.0   V  2.0
# 3               7.0  2019.0  4.0  5.0  2.0  ...   V  2.0   V  2.0   V  1.0
# 4               7.0  2019.0  4.0  6.0  1.0  ...   V  2.0   V  2.0   V  1.0
#
#   V23  H24 V24  \
# 0   V  1.0   V
# 1   V  2.0   V
# 2   V  2.0   V
# 3   V  2.0   V
# 4   V  3.0   V
#
# ...

# %%
data.to_csv('air_quality_2019.csv')

# %%
file_list1 = [f for f in os.listdir('../bcn_open_data/Aire/2020') if f.endswith('.csv')]
print(file_list1)
# Out:
# ['2020_04_Abril_qualitat_aire_BCN.csv', '2020_05_Maig_qualitat_aire_BCN.csv', '2020_06_Juny_qualitat_aire_BCN.csv', '2020_07_Juliol_qualitat_aire_BCN.csv', '2020_08_Agost_qualitat_aire_BCN.csv', '2020_09_Setembre_qualitat_aire_BCN.csv', '2020_10_Octubre_qualitat_aire_BCN.csv']

# %%
data_sets1 = [pd.read_csv(os.path.join('../bcn_open_data/Aire/2020', f)) for f in file_list1]
data1 = pd.concat(data_sets1, axis=0)
data1.head()
# Out:
#    CODI_PROVINCIA  PROVINCIA  CODI_MUNICIPI   MUNICIPI  ESTACIO  \
# 0               8  Barcelona             19  Barcelona        4
# 1               8  Barcelona             19  Barcelona        4
# 2               8  Barcelona             19  Barcelona        4
# 3               8  Barcelona             19  Barcelona        4
# 4               8  Barcelona             19  Barcelona        4
#
#    CODI_CONTAMINANT   ANY  MES  DIA  H01  ...  H20  V20  H21  V21  H22  V22  \
# 0                 7  2020    4    1  1.0  ...  1.0    V  1.0    V  1.0    V
# 1                 7  2020    4    2  1.0  ...  3.0    V  1.0    V  1.0    V
# 2                 7  2020    4    3  2.0  ...  1.0    V  1.0    V  1.0    V
# 3                 7  2020    4    4  3.0  ...  2.0    V  1.0    V  1.0    V
# 4                 7  2020    4    5  1.0  ...  1.0    V  1.0    V  4.0    V
#
#    H23  V23  H24  V24
# 0  1.0    V  1.0    V
# 1  1.0    V  1.0    V
# 2  1.0    V  2.0    V
# 3  1.0    V  NaN    N
# ...

# %%
data1.to_csv('air_quality_2020.csv')
