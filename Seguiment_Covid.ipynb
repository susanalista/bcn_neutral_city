# %%
import pandas as pd

# %%
df = pd.read_csv('../bcn_open_data/2020-seguiment-covid19-bcn.csv')

# %%
df.head()
# Out:
#   Data_Indicador Frequencia_Indicador  Territori  \
# 0     2020-02-26                Diari  Barcelona
# 1     2020-02-27                Diari  Barcelona
# 2     2020-02-28                Diari  Barcelona
# 3     2020-02-29                Diari  Barcelona
# 4     2020-03-01                Diari  Barcelona
#
#                   Nom_Indicador            Nom_Variable  Valor  Unitat  \
# 0  Casos de Covid19 a Barcelona  Nombre de casos diaris    0.0  Nombre
# 1  Casos de Covid19 a Barcelona  Nombre de casos diaris    0.0  Nombre
# 2  Casos de Covid19 a Barcelona  Nombre de casos diaris    0.0  Nombre
# 3  Casos de Covid19 a Barcelona  Nombre de casos diaris    0.0  Nombre
# 4  Casos de Covid19 a Barcelona  Nombre de casos diaris    0.0  Nombre
#
#                                     Font
# 0  Agència de Salut Pública de Barcelona
# 1  Agència de Salut Pública de Barcelona
# 2  Agència de Salut Pública de Barcelona
# 3  Agència de Salut Pública de Barcelona
# ...

# %%
df.tail()
# Out:
#       Data_Indicador Frequencia_Indicador  Territori  \
# 25063     2020-05-14                Diari  Barcelona
# 25064     2020-05-14                Diari  Barcelona
# 25065     2020-05-16                Diari  Barcelona
# 25066     2020-05-16                Diari  Barcelona
# 25067     2020-05-16                Diari  Barcelona
#
#                                            Nom_Indicador  \
# 25063  Enquesta opinió: Valoració de la gestió del Go...
# 25064  Enquesta opinió: Valoració de la gestió del Go...
# 25065  Enquesta opinió: Valoració de la gestió del Go...
# 25066  Enquesta opinió: Valoració de la gestió del Go...
# 25067  Enquesta opinió: Valoració de la gestió del Go...
#
#                  Nom_Variable  Valor Unitat  \
# 25063        Normal / regular   11.8      %
# 25064  Dolenta / molt dolenta   43.7      %
# 25065        Molt bona / bona   43.0      %
# 25066        Normal / regular   11.1      %
# 25067  Dolenta / molt dolenta   42.4      %
#
# ...

# %%
df.dtypes
# Out:
# Data_Indicador           object
# Frequencia_Indicador     object
# Territori                object
# Nom_Indicador            object
# Nom_Variable             object
# Valor                   float64
# Unitat                   object
# Font                     object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25068 entries, 0 to 25067
# Data columns (total 8 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Data_Indicador        25068 non-null  object
#  1   Frequencia_Indicador  25068 non-null  object
#  2   Territori             25068 non-null  object
#  3   Nom_Indicador         25068 non-null  object
#  4   Nom_Variable          23996 non-null  object
#  5   Valor                 24681 non-null  float64
#  6   Unitat                25068 non-null  object
#  7   Font                  25068 non-null  object
# dtypes: float64(1), object(7)
# memory usage: 1.5+ MB

# %%
df['Nom_Indicador'].unique()
# Out:
# array(['Casos de Covid19 a Barcelona', 'Casos de Covid19 a Catalunya',
#        'Casos de Covid19 a Espanya',
#        'Casos de Covid19 a Barcelona (acumulat)',
#        'Casos de Covid19 a Catalunya (acumulat)',
#        'Casos de Covid19 a Espanya (acumulat)',
#        'Casos de Covid19 als hospitals de Barcelona',
#        'Professionals inhàbils del consorci sanitari',
#        'Nombre de casos positius per barri',
#        'Incidència de casos positius per barris: taxes per 100.000 habitants',
#        'Defuncions registrades a Barcelona',
#        'Defuncions a Barcelona (estimació)',
#        'Defuncions a Catalunya (estimació)',
#        'Defuncions a Espanya (estimació)',
#        'Contaminants ambientals estació fons Palau Reial: NO2 i PM10',
#        'Contaminants ambientals estació trànsit Eixample: NO2 i PM10',
#        'Contaminació acústica. Dades dels sonòmetres',
#        'Temperatura mitjana diària',
#        'Velocitat mitjana diària del vent a 10m',
# ...

# %%
(df.Nom_Indicador == "Percentatge de mobilitat de vehicles sobre l'habitual").sum()
# Out:
# 920

# %%
mobility = df[df.Nom_Indicador =="Percentatge de mobilitat de vehicles sobre l'habitual"]

# %%
mobility
# Out:
#       Data_Indicador Frequencia_Indicador  Territori  \
# 15400     2020-03-02                Diari  Barcelona
# 15401     2020-03-03                Diari  Barcelona
# 15402     2020-03-04                Diari  Barcelona
# 15403     2020-03-05                Diari  Barcelona
# 15404     2020-03-06                Diari  Barcelona
# ...              ...                  ...        ...
# 16315     2020-10-14                Diari  Barcelona
# 16316     2020-10-15                Diari  Barcelona
# 16317     2020-10-16                Diari  Barcelona
# 16318     2020-10-17                Diari  Barcelona
# 16319     2020-10-18                Diari  Barcelona
#
#                                            Nom_Indicador  Nom_Variable  Valor  \
# 15400  Percentatge de mobilitat de vehicles sobre l'h...      Accessos   -0.4
# 15401  Percentatge de mobilitat de vehicles sobre l'h...      Accessos   -1.4
# 15402  Percentatge de mobilitat de vehicles sobre l'h...      Accessos    0.3
# ...

# %%
flights = df[df.Nom_Indicador == "Operacions d'aeronaus a l'aeroport de Barcelona-El Prat segons origen/destinació"]

# %%
flights
# Out:
#       Data_Indicador Frequencia_Indicador  Territori  \
# 14374     2019-01-01              Mensual  Barcelona
# 14375     2019-02-01              Mensual  Barcelona
# 14376     2019-03-01              Mensual  Barcelona
# 14377     2019-04-01              Mensual  Barcelona
# 14378     2019-05-01              Mensual  Barcelona
# ...              ...                  ...        ...
# 14432     2020-05-01              Mensual  Barcelona
# 14433     2020-06-01              Mensual  Barcelona
# 14434     2020-07-01              Mensual  Barcelona
# 14435     2020-08-01              Mensual  Barcelona
# 14436     2020-09-01              Mensual  Barcelona
#
#                                            Nom_Indicador         Nom_Variable  \
# 14374  Operacions d'aeronaus a l'aeroport de Barcelon...              Espanya
# 14375  Operacions d'aeronaus a l'aeroport de Barcelon...              Espanya
# 14376  Operacions d'aeronaus a l'aeroport de Barcelon...              Espanya
# ...

# %%
visitors = df[df.Nom_Indicador == "Visitants a Barcelona segons pais d'origen"]

# %%
visitors
# Out:
#       Data_Indicador Frequencia_Indicador Territori  \
# 19278     2020-01-02                Diari       Món
# 19279     2020-01-02                Diari       Món
# 19280     2020-01-02                Diari       Món
# 19281     2020-01-02                Diari       Món
# 19282     2020-01-02                Diari       Món
# ...              ...                  ...       ...
# 20436     2020-08-23                Diari       Món
# 20437     2020-08-23                Diari       Món
# 20438     2020-08-23                Diari       Món
# 20439     2020-08-23                Diari       Món
# 20440     2020-08-23                Diari       Món
#
#                                     Nom_Indicador       Nom_Variable    Valor  \
# 19278  Visitants a Barcelona segons pais d'origen             França  65199.0
# 19279  Visitants a Barcelona segons pais d'origen         Regne Unit  20247.0
# 19280  Visitants a Barcelona segons pais d'origen             Itàlia  36367.0
# ...

# %%
vessels = df[df.Nom_Indicador == 'Escales realitzades al port de Barcelona per tipus de vaixell']

# %%
vessels
# Out:
#       Data_Indicador Frequencia_Indicador  Territori  \
# 14531     2018-12-31                Diari  Barcelona
# 14532     2018-12-31                Diari  Barcelona
# 14533     2018-12-31                Diari  Barcelona
# 14534     2018-12-31                Diari  Barcelona
# 14535     2019-01-07                Diari  Barcelona
# ...              ...                  ...        ...
# 14865     2020-10-05                Diari  Barcelona
# 14866     2020-10-05                Diari  Barcelona
# 14867     2020-10-12                Diari  Barcelona
# 14868     2020-10-12                Diari  Barcelona
# 14869     2020-10-12                Diari  Barcelona
#
#                                            Nom_Indicador    Nom_Variable  \
# 14531  Escales realitzades al port de Barcelona per t...          Altres
# 14532  Escales realitzades al port de Barcelona per t...         Càrrega
# 14533  Escales realitzades al port de Barcelona per t...  Creuers i Iots
# ...

# %%
polution = df[df.Nom_Indicador == "Contaminants ambientals estació trànsit Eixample: NO2 i PM10"]

# %%
polution
# Out:
#      Data_Indicador Frequencia_Indicador  Territori  \
# 5234     2020-02-01                Diari  Barcelona
# 5235     2020-02-01                Diari  Barcelona
# 5236     2020-02-01                Diari  Barcelona
# 5237     2020-02-02                Diari  Barcelona
# 5238     2020-02-02                Diari  Barcelona
# ...             ...                  ...        ...
# 6018     2020-10-22                Diari  Barcelona
# 6019     2020-10-22                Diari  Barcelona
# 6020     2020-10-23                Diari  Barcelona
# 6021     2020-10-23                Diari  Barcelona
# 6022     2020-10-23                Diari  Barcelona
#
#                                           Nom_Indicador      Nom_Variable  \
# 5234  Contaminants ambientals estació trànsit Eixamp...  Màxim horari NO2
# 5235  Contaminants ambientals estació trànsit Eixamp...       Mitjana NO2
# 5236  Contaminants ambientals estació trànsit Eixamp...      Mitjana PM10
# ...

# %%
public_mobility = df[df.Nom_Indicador == "Percentatge de demanda de transport públic sobre l'habitual"]

# %%
public_mobility
# Out:
#       Data_Indicador Frequencia_Indicador  Territori  \
# 14870     2020-03-08                Diari  Barcelona
# 14871     2020-03-09                Diari  Barcelona
# 14872     2020-03-10                Diari  Barcelona
# 14873     2020-03-11                Diari  Barcelona
# 14874     2020-03-12                Diari  Barcelona
# ...              ...                  ...        ...
# 15395     2020-06-17                Diari  Barcelona
# 15396     2020-06-18                Diari  Barcelona
# 15397     2020-06-19                Diari  Barcelona
# 15398     2020-06-20                Diari  Barcelona
# 15399     2020-06-21                Diari  Barcelona
#
#                                            Nom_Indicador Nom_Variable   Valor  \
# 14870  Percentatge de demanda de transport públic sob...          FGC  100.00
# 14871  Percentatge de demanda de transport públic sob...          FGC   98.77
# 14872  Percentatge de demanda de transport públic sob...          FGC   96.26
# ...
